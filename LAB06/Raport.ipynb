# %% [markdown]
# # LAB06: Instrumentet Matëse në Fizikë
#
# **Studenti:** Klaus Dragjoshi
#
# **Lënda:** Hyrje Laborator (Fizike dhe Shkenca Kompjuterike)
#
# **Data:** 15 Prill 2026
#
# ---
#
# ## 1. Qëllimi i Punës Laboratorike
#
# Qëllimi i këtij laboratori është njohja praktike me instrumentet kryesore që përdoren për matjen e gjatësisë dhe masës.
# Përmes kësaj detyre, synojmë:
# * Të kuptojmë parimin e punës së secilit instrument.
# * Të përcaktojmë vlerën më të vogël të shkallës (VMS) për secilin mjet.
# * Të kryejmë matje direkte mbi objekte të ndryshme dhe të dokumentojmë saktësinë e tyre.

# %% [markdown]
# ## 2. Instrumentet e përdorura dhe funksioni i tyre
#
# Gjatë këtij laboratori kemi përdorur pajisjet e mëposhtme:
#
# 1. **Vizorja Milimetrike:**
#    * *Përdorimi:* Shërben për matjen e gjatësive të thjeshta dhe të drejta ku nuk kërkohet saktësi e lartë.
#    * *Saktësia:* Zakonisht $1 \text{ mm}$.
#
# 2. **Kalibri:**
#    * *Përdorimi:* Instrument i gjithanshëm që shërben për matjen e diametrave të jashtëm, diametrave të brendshëm (p.sh. gryka e një epruvete) dhe thellësisë.
#    * *Saktësia:* $0.1 \text{ mm}$ ose $0.05 \text{ mm}$.
#
# 3. **Mikrometri:**
#    * *Përdorimi:* Shërben për matjen e dimensioneve shumë të vogla si trashësia e një flete, diametri i një teli ose i një sferë të vogël metalike.
#    * *Saktësia:* Shumë e lartë, deri në $0.01 \text{ mm}$.
#
# 4. **Sferometri:**
#    * *Përdorimi:* Përdoret specifikisht për të matur rrezen e kurbaturës së sipërfaqeve sferike ose trashësinë e objekteve të rrafshëta e të holla.
#
# 5. **Peshorja Elektronike:**
#    * *Përdorimi:* Shërben për përcaktimin e masës së objekteve me një lexim të shpejtë digjital.
#    * *Saktësia:* Varion nga $0.1 \text{ g}$ deri në $0.01 \text{ g}$ (sipas modelit).
#
# 6. **Peshorja Manuale:**
#    * *Përdorimi:* Përcaktimi i masës përmes krahasimit të peshave etalon në dy krahët e peshores deri në arritjen e ekuilibrit.

# %% [markdown]
# ## 3. Matjet Eksperimentale (Të dhënat nga laboratori)
#
# Në bazë të punës praktike, u morën këto rezultate:
#
# ### A. Matje me Vizore
# *Objekti:* Objekt druri me formë kuboidi
# * *Gjatësia:* $14.5 \text{ cm}$
# * *Gjerësia:* $4.1 \text{ cm}$
# * *Lartësia:* $1.6 \text{ cm}$
#
# ### B. Matje me Kalibër
# *Objekti:* Pulti i Projektorit
# * *Lartësia:* $7.12 \text{ mm}$
# * *Gjerësia:* $40.2 \text{ mm}$
# * *Gjatësia:* $86.24 \text{ mm}$
#
# ### C. Matja e Masës (Peshore Manuale)
# *Objekti:* Telefon iPhone 14 Pro
# * *Masa ($m$):* $290 \text{ g}$
#
# * ### D. Matja e një Globi të vogël (Sferometer)
# *Objekti:* Glob dekorativ (Sferë)
# * *Instrumenti:* Kalibër (për diametrin e jashtëm)
# * *Diametri i matur ($D$):* $120.4 \text{ mm}$ (ose $12.04 \text{ cm}$)
# * *Instrumenti alternative:* Sferometër (për të matur kurbaturën e sipërfaqes)
# * *Lartësia e matur ($h$):* $4.52 \text{ mm}$
#
# ### E. Matja e Diametrit të Telit (Mikrometër)
# *Objekti:* Tel përcjellës (Bakri)
# * *Instrumenti:* Mikrometër
# * *Vlera e matur ($d$):* $0.50 \text{ mm}$
#
# ### F. Matja e Masës (Peshore Elektronike)
# *Objekti:* Këllëf (Case) për iPhone 14 Pro
# * *Instrumenti:* Peshore Elektronike
# * *Masa ($m$):* $25 \text{ g}$

# %% [markdown]
# ## 4. Tabela Përmbledhëse e të Dhënave
#
# | Objekti | Instrumenti | Madhësia Fizike | Vlera e Matur | Pasiguria (Saktësia) |
# | :--- | :--- | :--- | :--- | :--- |
# | *Objekt Druri* | Vizore | Përmasat ($l, b, h$) | $14.5 \times 4.1 \times 1.6 \text{ cm}$ | $\pm 0.1 \text{ cm}$ |
# | *Pulti i Projektorit* | Kalibër | Përmasat ($l, b, h$) | $86.24 \times 40.2 \times 7.12 \text{ mm}$ | $\pm 0.02 \text{ mm}$ |
# | *iPhone 14 Pro* | Peshore Manuale | Masa ($m$) | $290 \text{ g}$ | $\pm 0.5 \text{ g}$ |
# | *Këllëf (Case)* | Peshore Elektronike | Masa ($m$) | $25 \text{ g}$ | $\pm 0.1 \text{ g}$ |
# | *Glob Dekorativ* | Kalibër | Diametri ($D$) | $120.4 \text{ mm}$ | $\pm 0.1 \text{ mm}$ |
# | *Sipërfaqe Globi* | Sferometër | Kurbatura ($h$) | $4.52 \text{ mm}$ | $\pm 0.01 \text{ mm}$ |
# | *Tel Bakri* | Mikrometër | Diametri ($d$) | $0.50 \text{ mm}$ | $\pm 0.01 \text{ mm}$ |

# %% [markdown]
# ## 5. Përfundime
#
# 1. *Përzgjedhja e Instrumentit:* Zgjedhja e mjetit matës duhet të bëhet në përputhje me përmasat e objektit dhe saktësinë e kërkuar. Për shembull, përdorimi i vizores për telin me diametër $0.50 \text{ mm}$ do të ishte i pamundur, ndërsa *mikrometri* dha një rezultat të saktë.
# 2. *Analiza e Saktësisë:* Vumë re se instrumentet me nonius (kalibri) dhe ato me vidë mikrometrike (mikrometri, sferometri) minimizojnë pasigurinë eksperimentale, duke na lejuar të marrim matje deri në *dy shifra pas presjes* ($0.01 \text{ mm}$).
# 3. *Krahasimi i Peshoreve:* Matja e masës me *peshore manuale* (iPhone 14 Pro: $290 \text{ g}$) kërkon më shumë kohë për vendosjen e ekuilibrit, ndërsa *peshorja elektronike* (Këllëfi: $25 \text{ g}$) ofron një lexim të menjëhershëm dhe eliminon gabimet subjektive të syrit.
# 4. *Gabimet eksperimentale:* Gjatë matjeve duhet pasur kujdes nga gabimi i paralaksit (pozicioni i gabuar i syrit) dhe saktësia e vendosjes së instrumentit mbi objekt, veçanërisht te sferometri ku kërkohet kontakt preciz me sipërfaqen.
